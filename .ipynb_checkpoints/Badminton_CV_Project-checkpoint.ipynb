# %% [markdown]
# # Setup Paths

# %%
WORKSPACE_PATH = 'Tensorflow/workspace'
SCRIPTS_PATH = 'Tensorflow/scripts'
APIMODEL_PATH = 'Tensorflow/models'
ANNOTATION_PATH = WORKSPACE_PATH+'/annotations'
IMAGE_PATH = WORKSPACE_PATH+'/images'
MODEL_PATH = WORKSPACE_PATH+'/models'
PRETRAINED_MODEL_PATH = WORKSPACE_PATH+'/pre-trained-models'
CONFIG_PATH = MODEL_PATH+'/my_ssd_mobnet/pipeline.config'
CHECKPOINT_PATH = MODEL_PATH+'/my_ssd_mobnet/'

# %% [markdown]
# # Create Label Map

# %%
labels = [{'name':'racket', 'id':1}, 
          {'name':'shuttle', 'id':2}, 
          {'name':'human', 'id':3}]

with open(ANNOTATION_PATH + '\label_map.pbtxt', 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # Create TF records

# %%
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x{IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # Download TF Models Pretrained Models from Tensorflow Model Zoo

# %%
# !cd Tensorflow && git clone https://github.com/tensorflow/models

# %%
#wget.download('http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz')
#!mv ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz {PRETRAINED_MODEL_PATH}
#!cd {PRETRAINED_MODEL_PATH} && tar -zxvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz

# %% [markdown]
# # Copy Model Config to Training Folder

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet'

# %%
# !mkdir {'Tensorflow\workspace\models\\'+CUSTOM_MODEL_NAME}
# !copy {(PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config').replace('/', '\\')} {(MODEL_PATH+'/'+CUSTOM_MODEL_NAME).replace('/', '\\')}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
CONFIG_PATH = MODEL_PATH+'/'+CUSTOM_MODEL_NAME+'/pipeline.config'

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = 3
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/train.record']
pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # Train the model

# %%
print("""python {}/research/object_detection/model_main_tf2.py --model_dir={}/{} --pipeline_config_path={}/{}/pipeline.config --num_train_steps=20000""".format(APIMODEL_PATH, MODEL_PATH,CUSTOM_MODEL_NAME,MODEL_PATH,CUSTOM_MODEL_NAME))
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=20000

# %%
# !python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=20000
# Out:
# C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2023-05-12 15:42:23.411584: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-12 15:42:23.984805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2774 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0512 15:42:24.112607  8752 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 20000
# I0512 15:42:24.118783  8752 config_util.py:552] Maybe overwriting train_steps: 20000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0512 15:42:24.118783  8752 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0512 15:42:24.175415  8752 deprecation.py:350] From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0512 15:42:24.193981  8752 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0512 15:42:24.193981  8752 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0512 15:42:24.193981  8752 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0512 15:42:24.193981  8752 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0512 15:42:24.206518  8752 deprecation.py:350] From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0512 15:42:24.238481  8752 deprecation.py:350] From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0512 15:42:30.443972  8752 deprecation.py:350] From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0512 15:42:33.233866  8752 deprecation.py:350] From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0512 15:42:34.902408  8752 deprecation.py:350] From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0512 15:42:42.827145  2524 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0512 15:42:50.935876  9820 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-05-12 15:42:55.112950: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.424175  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.428724  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.431745  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.432693  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.436311  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.438274  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.442278  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.444278  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.446801  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 15:42:58.448799  8752 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0512 15:43:00.791954 20160 deprecation.py:554] From C:\Users\LMT\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0512 15:43:01.800449 20160 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0512 15:43:07.109214  9256 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0512 15:43:11.703898  7912 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0512 15:43:16.687048  4400 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.490s
# I0512 15:43:49.386109  8752 model_lib_v2.py:705] Step 100 per-step time 0.490s
# INFO:tensorflow:{'Loss/classification_loss': 0.38412505,
#  'Loss/localization_loss': 0.26105747,
#  'Loss/regularization_loss': 0.15399623,
#  'Loss/total_loss': 0.7991787,
#  'learning_rate': 0.0319994}
# I0512 15:43:49.387115  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.38412505,
#  'Loss/localization_loss': 0.26105747,
#  'Loss/regularization_loss': 0.15399623,
#  'Loss/total_loss': 0.7991787,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.198s
# I0512 15:44:09.209832  8752 model_lib_v2.py:705] Step 200 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.22726929,
#  'Loss/localization_loss': 0.21665029,
#  'Loss/regularization_loss': 0.15398334,
#  'Loss/total_loss': 0.59790295,
#  'learning_rate': 0.0373328}
# I0512 15:44:09.210832  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.22726929,
#  'Loss/localization_loss': 0.21665029,
#  'Loss/regularization_loss': 0.15398334,
#  'Loss/total_loss': 0.59790295,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.201s
# I0512 15:44:29.294212  8752 model_lib_v2.py:705] Step 300 per-step time 0.201s
# INFO:tensorflow:{'Loss/classification_loss': 0.19880073,
#  'Loss/localization_loss': 0.16195668,
#  'Loss/regularization_loss': 0.15384436,
#  'Loss/total_loss': 0.51460177,
#  'learning_rate': 0.0426662}
# I0512 15:44:29.294212  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.19880073,
#  'Loss/localization_loss': 0.16195668,
#  'Loss/regularization_loss': 0.15384436,
#  'Loss/total_loss': 0.51460177,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.205s
# I0512 15:44:49.789595  8752 model_lib_v2.py:705] Step 400 per-step time 0.205s
# INFO:tensorflow:{'Loss/classification_loss': 0.20131521,
#  'Loss/localization_loss': 0.10729856,
#  'Loss/regularization_loss': 0.15367012,
#  'Loss/total_loss': 0.4622839,
#  'learning_rate': 0.047999598}
# I0512 15:44:49.789595  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.20131521,
#  'Loss/localization_loss': 0.10729856,
#  'Loss/regularization_loss': 0.15367012,
#  'Loss/total_loss': 0.4622839,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.203s
# I0512 15:45:11.903780  8752 model_lib_v2.py:705] Step 500 per-step time 0.203s
# INFO:tensorflow:{'Loss/classification_loss': 0.12521985,
#  'Loss/localization_loss': 0.046782598,
#  'Loss/regularization_loss': 0.15349881,
#  'Loss/total_loss': 0.32550126,
#  'learning_rate': 0.053333}
# I0512 15:45:11.903780  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.12521985,
#  'Loss/localization_loss': 0.046782598,
#  'Loss/regularization_loss': 0.15349881,
#  'Loss/total_loss': 0.32550126,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.224s
# I0512 15:45:32.480139  8752 model_lib_v2.py:705] Step 600 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.11275031,
#  'Loss/localization_loss': 0.06975178,
#  'Loss/regularization_loss': 0.1531446,
#  'Loss/total_loss': 0.3356467,
#  'learning_rate': 0.0586664}
# I0512 15:45:32.481113  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.11275031,
#  'Loss/localization_loss': 0.06975178,
#  'Loss/regularization_loss': 0.1531446,
#  'Loss/total_loss': 0.3356467,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.204s
# I0512 15:45:54.624246  8752 model_lib_v2.py:705] Step 700 per-step time 0.204s
# INFO:tensorflow:{'Loss/classification_loss': 0.107731804,
#  'Loss/localization_loss': 0.07313849,
#  'Loss/regularization_loss': 0.1527925,
#  'Loss/total_loss': 0.3336628,
#  'learning_rate': 0.0639998}
# I0512 15:45:54.625246  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.107731804,
#  'Loss/localization_loss': 0.07313849,
#  'Loss/regularization_loss': 0.1527925,
#  'Loss/total_loss': 0.3336628,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.222s
# I0512 15:46:15.493500  8752 model_lib_v2.py:705] Step 800 per-step time 0.222s
# INFO:tensorflow:{'Loss/classification_loss': 0.14285827,
#  'Loss/localization_loss': 0.05429192,
#  'Loss/regularization_loss': 0.15235715,
#  'Loss/total_loss': 0.34950733,
#  'learning_rate': 0.069333196}
# I0512 15:46:15.493500  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.14285827,
#  'Loss/localization_loss': 0.05429192,
#  'Loss/regularization_loss': 0.15235715,
#  'Loss/total_loss': 0.34950733,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.215s
# I0512 15:46:36.608809  8752 model_lib_v2.py:705] Step 900 per-step time 0.215s
# INFO:tensorflow:{'Loss/classification_loss': 0.17421192,
#  'Loss/localization_loss': 0.064537525,
#  'Loss/regularization_loss': 0.15181218,
#  'Loss/total_loss': 0.39056164,
#  'learning_rate': 0.074666604}
# I0512 15:46:36.608809  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.17421192,
#  'Loss/localization_loss': 0.064537525,
#  'Loss/regularization_loss': 0.15181218,
#  'Loss/total_loss': 0.39056164,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.209s
# I0512 15:46:59.222618  8752 model_lib_v2.py:705] Step 1000 per-step time 0.209s
# INFO:tensorflow:{'Loss/classification_loss': 0.09574437,
#  'Loss/localization_loss': 0.06582378,
#  'Loss/regularization_loss': 0.1513024,
#  'Loss/total_loss': 0.31287056,
#  'learning_rate': 0.08}
# I0512 15:46:59.223508  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.09574437,
#  'Loss/localization_loss': 0.06582378,
#  'Loss/regularization_loss': 0.1513024,
#  'Loss/total_loss': 0.31287056,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.251s
# I0512 15:47:22.649665  8752 model_lib_v2.py:705] Step 1100 per-step time 0.251s
# INFO:tensorflow:{'Loss/classification_loss': 0.09298714,
#  'Loss/localization_loss': 0.07282202,
#  'Loss/regularization_loss': 0.15074682,
#  'Loss/total_loss': 0.31655598,
#  'learning_rate': 0.07999918}
# I0512 15:47:22.649665  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.09298714,
#  'Loss/localization_loss': 0.07282202,
#  'Loss/regularization_loss': 0.15074682,
#  'Loss/total_loss': 0.31655598,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.211s
# I0512 15:47:43.734401  8752 model_lib_v2.py:705] Step 1200 per-step time 0.211s
# INFO:tensorflow:{'Loss/classification_loss': 0.104995735,
#  'Loss/localization_loss': 0.039944932,
#  'Loss/regularization_loss': 0.15012386,
#  'Loss/total_loss': 0.29506454,
#  'learning_rate': 0.079996705}
# I0512 15:47:43.735420  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.104995735,
#  'Loss/localization_loss': 0.039944932,
#  'Loss/regularization_loss': 0.15012386,
#  'Loss/total_loss': 0.29506454,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.210s
# I0512 15:48:06.458306  8752 model_lib_v2.py:705] Step 1300 per-step time 0.210s
# INFO:tensorflow:{'Loss/classification_loss': 0.06501382,
#  'Loss/localization_loss': 0.03259851,
#  'Loss/regularization_loss': 0.1494286,
#  'Loss/total_loss': 0.24704093,
#  'learning_rate': 0.0799926}
# I0512 15:48:06.458306  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.06501382,
#  'Loss/localization_loss': 0.03259851,
#  'Loss/regularization_loss': 0.1494286,
#  'Loss/total_loss': 0.24704093,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.227s
# I0512 15:48:27.437402  8752 model_lib_v2.py:705] Step 1400 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.12781528,
#  'Loss/localization_loss': 0.06584923,
#  'Loss/regularization_loss': 0.14875753,
#  'Loss/total_loss': 0.34242204,
#  'learning_rate': 0.07998685}
# I0512 15:48:27.438431  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.12781528,
#  'Loss/localization_loss': 0.06584923,
#  'Loss/regularization_loss': 0.14875753,
#  'Loss/total_loss': 0.34242204,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.213s
# I0512 15:48:48.782448  8752 model_lib_v2.py:705] Step 1500 per-step time 0.213s
# INFO:tensorflow:{'Loss/classification_loss': 0.10469018,
#  'Loss/localization_loss': 0.05788821,
#  'Loss/regularization_loss': 0.14805315,
#  'Loss/total_loss': 0.31063154,
#  'learning_rate': 0.07997945}
# I0512 15:48:48.782448  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.10469018,
#  'Loss/localization_loss': 0.05788821,
#  'Loss/regularization_loss': 0.14805315,
#  'Loss/total_loss': 0.31063154,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.212s
# I0512 15:49:11.714389  8752 model_lib_v2.py:705] Step 1600 per-step time 0.212s
# INFO:tensorflow:{'Loss/classification_loss': 0.10181367,
#  'Loss/localization_loss': 0.05653591,
#  'Loss/regularization_loss': 0.1473416,
#  'Loss/total_loss': 0.30569118,
#  'learning_rate': 0.079970405}
# I0512 15:49:11.714389  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.10181367,
#  'Loss/localization_loss': 0.05653591,
#  'Loss/regularization_loss': 0.1473416,
#  'Loss/total_loss': 0.30569118,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.229s
# I0512 15:49:32.878192  8752 model_lib_v2.py:705] Step 1700 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.057118684,
#  'Loss/localization_loss': 0.038218115,
#  'Loss/regularization_loss': 0.14667074,
#  'Loss/total_loss': 0.24200754,
#  'learning_rate': 0.07995972}
# I0512 15:49:32.879199  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.057118684,
#  'Loss/localization_loss': 0.038218115,
#  'Loss/regularization_loss': 0.14667074,
#  'Loss/total_loss': 0.24200754,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.211s
# I0512 15:49:55.785117  8752 model_lib_v2.py:705] Step 1800 per-step time 0.211s
# INFO:tensorflow:{'Loss/classification_loss': 0.064515136,
#  'Loss/localization_loss': 0.020782186,
#  'Loss/regularization_loss': 0.14593324,
#  'Loss/total_loss': 0.23123056,
#  'learning_rate': 0.0799474}
# I0512 15:49:55.786119  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.064515136,
#  'Loss/localization_loss': 0.020782186,
#  'Loss/regularization_loss': 0.14593324,
#  'Loss/total_loss': 0.23123056,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.230s
# I0512 15:50:17.397307  8752 model_lib_v2.py:705] Step 1900 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.08584599,
#  'Loss/localization_loss': 0.050595682,
#  'Loss/regularization_loss': 0.14519519,
#  'Loss/total_loss': 0.28163686,
#  'learning_rate': 0.07993342}
# I0512 15:50:17.397307  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.08584599,
#  'Loss/localization_loss': 0.050595682,
#  'Loss/regularization_loss': 0.14519519,
#  'Loss/total_loss': 0.28163686,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.216s
# I0512 15:50:38.657505  8752 model_lib_v2.py:705] Step 2000 per-step time 0.216s
# INFO:tensorflow:{'Loss/classification_loss': 0.07205892,
#  'Loss/localization_loss': 0.01464879,
#  'Loss/regularization_loss': 0.14444017,
#  'Loss/total_loss': 0.23114789,
#  'learning_rate': 0.07991781}
# I0512 15:50:38.657505  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.07205892,
#  'Loss/localization_loss': 0.01464879,
#  'Loss/regularization_loss': 0.14444017,
#  'Loss/total_loss': 0.23114789,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.237s
# I0512 15:51:02.392488  8752 model_lib_v2.py:705] Step 2100 per-step time 0.237s
# INFO:tensorflow:{'Loss/classification_loss': 0.09995233,
#  'Loss/localization_loss': 0.043924198,
#  'Loss/regularization_loss': 0.14377694,
#  'Loss/total_loss': 0.28765345,
#  'learning_rate': 0.07990056}
# I0512 15:51:02.392488  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.09995233,
#  'Loss/localization_loss': 0.043924198,
#  'Loss/regularization_loss': 0.14377694,
#  'Loss/total_loss': 0.28765345,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.212s
# I0512 15:51:23.584681  8752 model_lib_v2.py:705] Step 2200 per-step time 0.212s
# INFO:tensorflow:{'Loss/classification_loss': 0.10922465,
#  'Loss/localization_loss': 0.023442185,
#  'Loss/regularization_loss': 0.14306098,
#  'Loss/total_loss': 0.2757278,
#  'learning_rate': 0.07988167}
# I0512 15:51:23.584681  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.10922465,
#  'Loss/localization_loss': 0.023442185,
#  'Loss/regularization_loss': 0.14306098,
#  'Loss/total_loss': 0.2757278,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.212s
# I0512 15:51:44.728625  8752 model_lib_v2.py:705] Step 2300 per-step time 0.212s
# INFO:tensorflow:{'Loss/classification_loss': 0.07267593,
#  'Loss/localization_loss': 0.026026016,
#  'Loss/regularization_loss': 0.1423336,
#  'Loss/total_loss': 0.24103555,
#  'learning_rate': 0.07986114}
# I0512 15:51:44.728625  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.07267593,
#  'Loss/localization_loss': 0.026026016,
#  'Loss/regularization_loss': 0.1423336,
#  'Loss/total_loss': 0.24103555,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.214s
# I0512 15:52:07.973868  8752 model_lib_v2.py:705] Step 2400 per-step time 0.214s
# INFO:tensorflow:{'Loss/classification_loss': 0.061547447,
#  'Loss/localization_loss': 0.039130706,
#  'Loss/regularization_loss': 0.14161591,
#  'Loss/total_loss': 0.24229407,
#  'learning_rate': 0.07983897}
# I0512 15:52:07.973868  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.061547447,
#  'Loss/localization_loss': 0.039130706,
#  'Loss/regularization_loss': 0.14161591,
#  'Loss/total_loss': 0.24229407,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.232s
# I0512 15:52:29.346108  8752 model_lib_v2.py:705] Step 2500 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.09092776,
#  'Loss/localization_loss': 0.03081703,
#  'Loss/regularization_loss': 0.14089647,
#  'Loss/total_loss': 0.26264125,
#  'learning_rate': 0.079815164}
# I0512 15:52:29.346108  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.09092776,
#  'Loss/localization_loss': 0.03081703,
#  'Loss/regularization_loss': 0.14089647,
#  'Loss/total_loss': 0.26264125,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.217s
# I0512 15:52:51.091549  8752 model_lib_v2.py:705] Step 2600 per-step time 0.217s
# INFO:tensorflow:{'Loss/classification_loss': 0.07801314,
#  'Loss/localization_loss': 0.04236386,
#  'Loss/regularization_loss': 0.14021666,
#  'Loss/total_loss': 0.26059365,
#  'learning_rate': 0.07978972}
# I0512 15:52:51.092512  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.07801314,
#  'Loss/localization_loss': 0.04236386,
#  'Loss/regularization_loss': 0.14021666,
#  'Loss/total_loss': 0.26059365,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.213s
# I0512 15:53:14.135780  8752 model_lib_v2.py:705] Step 2700 per-step time 0.213s
# INFO:tensorflow:{'Loss/classification_loss': 0.089442216,
#  'Loss/localization_loss': 0.031773794,
#  'Loss/regularization_loss': 0.13950816,
#  'Loss/total_loss': 0.2607242,
#  'learning_rate': 0.07976264}
# I0512 15:53:14.135780  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.089442216,
#  'Loss/localization_loss': 0.031773794,
#  'Loss/regularization_loss': 0.13950816,
#  'Loss/total_loss': 0.2607242,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.231s
# I0512 15:53:35.499326  8752 model_lib_v2.py:705] Step 2800 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.06578967,
#  'Loss/localization_loss': 0.054283895,
#  'Loss/regularization_loss': 0.13880523,
#  'Loss/total_loss': 0.2588788,
#  'learning_rate': 0.07973392}
# I0512 15:53:35.500335  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.06578967,
#  'Loss/localization_loss': 0.054283895,
#  'Loss/regularization_loss': 0.13880523,
#  'Loss/total_loss': 0.2588788,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.215s
# I0512 15:53:58.689633  8752 model_lib_v2.py:705] Step 2900 per-step time 0.215s
# INFO:tensorflow:{'Loss/classification_loss': 0.12656942,
#  'Loss/localization_loss': 0.053626332,
#  'Loss/regularization_loss': 0.13809104,
#  'Loss/total_loss': 0.31828678,
#  'learning_rate': 0.07970358}
# I0512 15:53:58.689633  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.12656942,
#  'Loss/localization_loss': 0.053626332,
#  'Loss/regularization_loss': 0.13809104,
#  'Loss/total_loss': 0.31828678,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.232s
# I0512 15:54:20.623372  8752 model_lib_v2.py:705] Step 3000 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.053599387,
#  'Loss/localization_loss': 0.04368471,
#  'Loss/regularization_loss': 0.13737646,
#  'Loss/total_loss': 0.23466055,
#  'learning_rate': 0.0796716}
# I0512 15:54:20.623372  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.053599387,
#  'Loss/localization_loss': 0.04368471,
#  'Loss/regularization_loss': 0.13737646,
#  'Loss/total_loss': 0.23466055,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.239s
# I0512 15:54:44.088316  8752 model_lib_v2.py:705] Step 3100 per-step time 0.239s
# INFO:tensorflow:{'Loss/classification_loss': 0.05273718,
#  'Loss/localization_loss': 0.030113047,
#  'Loss/regularization_loss': 0.13665228,
#  'Loss/total_loss': 0.21950251,
#  'learning_rate': 0.07963799}
# I0512 15:54:44.088316  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.05273718,
#  'Loss/localization_loss': 0.030113047,
#  'Loss/regularization_loss': 0.13665228,
#  'Loss/total_loss': 0.21950251,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.214s
# I0512 15:55:07.226540  8752 model_lib_v2.py:705] Step 3200 per-step time 0.214s
# INFO:tensorflow:{'Loss/classification_loss': 0.057178035,
#  'Loss/localization_loss': 0.030297128,
#  'Loss/regularization_loss': 0.1359447,
#  'Loss/total_loss': 0.22341986,
#  'learning_rate': 0.07960275}
# I0512 15:55:07.227540  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.057178035,
#  'Loss/localization_loss': 0.030297128,
#  'Loss/regularization_loss': 0.1359447,
#  'Loss/total_loss': 0.22341986,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.232s
# I0512 15:55:29.050657  8752 model_lib_v2.py:705] Step 3300 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.07802265,
#  'Loss/localization_loss': 0.035036955,
#  'Loss/regularization_loss': 0.13525788,
#  'Loss/total_loss': 0.2483175,
#  'learning_rate': 0.07956588}
# I0512 15:55:29.050657  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.07802265,
#  'Loss/localization_loss': 0.035036955,
#  'Loss/regularization_loss': 0.13525788,
#  'Loss/total_loss': 0.2483175,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.219s
# I0512 15:55:50.548882  8752 model_lib_v2.py:705] Step 3400 per-step time 0.219s
# INFO:tensorflow:{'Loss/classification_loss': 0.03305556,
#  'Loss/localization_loss': 0.022563176,
#  'Loss/regularization_loss': 0.13457881,
#  'Loss/total_loss': 0.19019754,
#  'learning_rate': 0.079527386}
# I0512 15:55:50.548882  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.03305556,
#  'Loss/localization_loss': 0.022563176,
#  'Loss/regularization_loss': 0.13457881,
#  'Loss/total_loss': 0.19019754,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.218s
# I0512 15:56:14.137743  8752 model_lib_v2.py:705] Step 3500 per-step time 0.218s
# INFO:tensorflow:{'Loss/classification_loss': 0.035160854,
#  'Loss/localization_loss': 0.009411847,
#  'Loss/regularization_loss': 0.13386929,
#  'Loss/total_loss': 0.178442,
#  'learning_rate': 0.07948727}
# I0512 15:56:14.138717  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.035160854,
#  'Loss/localization_loss': 0.009411847,
#  'Loss/regularization_loss': 0.13386929,
#  'Loss/total_loss': 0.178442,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.234s
# I0512 15:56:35.735877  8752 model_lib_v2.py:705] Step 3600 per-step time 0.234s
# INFO:tensorflow:{'Loss/classification_loss': 0.06432259,
#  'Loss/localization_loss': 0.032514565,
#  'Loss/regularization_loss': 0.13316596,
#  'Loss/total_loss': 0.23000312,
#  'learning_rate': 0.079445526}
# I0512 15:56:35.736875  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.06432259,
#  'Loss/localization_loss': 0.032514565,
#  'Loss/regularization_loss': 0.13316596,
#  'Loss/total_loss': 0.23000312,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.215s
# I0512 15:56:57.237064  8752 model_lib_v2.py:705] Step 3700 per-step time 0.215s
# INFO:tensorflow:{'Loss/classification_loss': 0.06790583,
#  'Loss/localization_loss': 0.02644799,
#  'Loss/regularization_loss': 0.13248207,
#  'Loss/total_loss': 0.22683588,
#  'learning_rate': 0.07940216}
# I0512 15:56:57.237064  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.06790583,
#  'Loss/localization_loss': 0.02644799,
#  'Loss/regularization_loss': 0.13248207,
#  'Loss/total_loss': 0.22683588,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.216s
# I0512 15:57:20.478780  8752 model_lib_v2.py:705] Step 3800 per-step time 0.216s
# INFO:tensorflow:{'Loss/classification_loss': 0.06955712,
#  'Loss/localization_loss': 0.035511386,
#  'Loss/regularization_loss': 0.13178104,
#  'Loss/total_loss': 0.23684955,
#  'learning_rate': 0.079357184}
# I0512 15:57:20.478780  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.06955712,
#  'Loss/localization_loss': 0.035511386,
#  'Loss/regularization_loss': 0.13178104,
#  'Loss/total_loss': 0.23684955,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.231s
# I0512 15:57:41.970408  8752 model_lib_v2.py:705] Step 3900 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.047717404,
#  'Loss/localization_loss': 0.014896434,
#  'Loss/regularization_loss': 0.13108641,
#  'Loss/total_loss': 0.19370025,
#  'learning_rate': 0.07931058}
# I0512 15:57:41.971408  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.047717404,
#  'Loss/localization_loss': 0.014896434,
#  'Loss/regularization_loss': 0.13108641,
#  'Loss/total_loss': 0.19370025,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.217s
# I0512 15:58:05.563917  8752 model_lib_v2.py:705] Step 4000 per-step time 0.217s
# INFO:tensorflow:{'Loss/classification_loss': 0.028855886,
#  'Loss/localization_loss': 0.012199649,
#  'Loss/regularization_loss': 0.13041154,
#  'Loss/total_loss': 0.17146707,
#  'learning_rate': 0.07926236}
# I0512 15:58:05.564949  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.028855886,
#  'Loss/localization_loss': 0.012199649,
#  'Loss/regularization_loss': 0.13041154,
#  'Loss/total_loss': 0.17146707,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.256s
# I0512 15:58:29.406580  8752 model_lib_v2.py:705] Step 4100 per-step time 0.256s
# INFO:tensorflow:{'Loss/classification_loss': 0.0890013,
#  'Loss/localization_loss': 0.034860134,
#  'Loss/regularization_loss': 0.12972659,
#  'Loss/total_loss': 0.25358802,
#  'learning_rate': 0.07921253}
# I0512 15:58:29.407622  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.0890013,
#  'Loss/localization_loss': 0.034860134,
#  'Loss/regularization_loss': 0.12972659,
#  'Loss/total_loss': 0.25358802,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.217s
# I0512 15:58:51.069886  8752 model_lib_v2.py:705] Step 4200 per-step time 0.217s
# INFO:tensorflow:{'Loss/classification_loss': 0.06831168,
#  'Loss/localization_loss': 0.017810931,
#  'Loss/regularization_loss': 0.12903975,
#  'Loss/total_loss': 0.21516237,
#  'learning_rate': 0.07916109}
# I0512 15:58:51.069886  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.06831168,
#  'Loss/localization_loss': 0.017810931,
#  'Loss/regularization_loss': 0.12903975,
#  'Loss/total_loss': 0.21516237,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.219s
# I0512 15:59:14.801297  8752 model_lib_v2.py:705] Step 4300 per-step time 0.219s
# INFO:tensorflow:{'Loss/classification_loss': 0.049078334,
#  'Loss/localization_loss': 0.04086076,
#  'Loss/regularization_loss': 0.12836242,
#  'Loss/total_loss': 0.2183015,
#  'learning_rate': 0.07910804}
# I0512 15:59:14.801297  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.049078334,
#  'Loss/localization_loss': 0.04086076,
#  'Loss/regularization_loss': 0.12836242,
#  'Loss/total_loss': 0.2183015,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.234s
# I0512 15:59:36.809491  8752 model_lib_v2.py:705] Step 4400 per-step time 0.234s
# INFO:tensorflow:{'Loss/classification_loss': 0.025633486,
#  'Loss/localization_loss': 0.010416096,
#  'Loss/regularization_loss': 0.127696,
#  'Loss/total_loss': 0.16374558,
#  'learning_rate': 0.07905338}
# I0512 15:59:36.809491  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.025633486,
#  'Loss/localization_loss': 0.010416096,
#  'Loss/regularization_loss': 0.127696,
#  'Loss/total_loss': 0.16374558,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.223s
# I0512 15:59:58.643309  8752 model_lib_v2.py:705] Step 4500 per-step time 0.223s
# INFO:tensorflow:{'Loss/classification_loss': 0.0446578,
#  'Loss/localization_loss': 0.03940876,
#  'Loss/regularization_loss': 0.12703685,
#  'Loss/total_loss': 0.21110341,
#  'learning_rate': 0.07899711}
# I0512 15:59:58.643309  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.0446578,
#  'Loss/localization_loss': 0.03940876,
#  'Loss/regularization_loss': 0.12703685,
#  'Loss/total_loss': 0.21110341,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.216s
# I0512 16:00:21.994883  8752 model_lib_v2.py:705] Step 4600 per-step time 0.216s
# INFO:tensorflow:{'Loss/classification_loss': 0.029695403,
#  'Loss/localization_loss': 0.012354801,
#  'Loss/regularization_loss': 0.12638369,
#  'Loss/total_loss': 0.1684339,
#  'learning_rate': 0.078939244}
# I0512 16:00:21.994883  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.029695403,
#  'Loss/localization_loss': 0.012354801,
#  'Loss/regularization_loss': 0.12638369,
#  'Loss/total_loss': 0.1684339,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.232s
# I0512 16:00:43.493129  8752 model_lib_v2.py:705] Step 4700 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.08392543,
#  'Loss/localization_loss': 0.017022599,
#  'Loss/regularization_loss': 0.12573503,
#  'Loss/total_loss': 0.22668307,
#  'learning_rate': 0.07887978}
# I0512 16:00:43.493129  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.08392543,
#  'Loss/localization_loss': 0.017022599,
#  'Loss/regularization_loss': 0.12573503,
#  'Loss/total_loss': 0.22668307,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.221s
# I0512 16:01:05.589828  8752 model_lib_v2.py:705] Step 4800 per-step time 0.221s
# INFO:tensorflow:{'Loss/classification_loss': 0.043469205,
#  'Loss/localization_loss': 0.019766193,
#  'Loss/regularization_loss': 0.12507363,
#  'Loss/total_loss': 0.18830903,
#  'learning_rate': 0.07881871}
# I0512 16:01:05.590823  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.043469205,
#  'Loss/localization_loss': 0.019766193,
#  'Loss/regularization_loss': 0.12507363,
#  'Loss/total_loss': 0.18830903,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.216s
# I0512 16:01:28.892402  8752 model_lib_v2.py:705] Step 4900 per-step time 0.216s
# INFO:tensorflow:{'Loss/classification_loss': 0.061843965,
#  'Loss/localization_loss': 0.016664641,
#  'Loss/regularization_loss': 0.12441832,
#  'Loss/total_loss': 0.20292693,
#  'learning_rate': 0.07875605}
# I0512 16:01:28.892402  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.061843965,
#  'Loss/localization_loss': 0.016664641,
#  'Loss/regularization_loss': 0.12441832,
#  'Loss/total_loss': 0.20292693,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.232s
# I0512 16:01:50.342962  8752 model_lib_v2.py:705] Step 5000 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.06507275,
#  'Loss/localization_loss': 0.021027593,
#  'Loss/regularization_loss': 0.12377021,
#  'Loss/total_loss': 0.20987055,
#  'learning_rate': 0.078691795}
# I0512 16:01:50.343964  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.06507275,
#  'Loss/localization_loss': 0.021027593,
#  'Loss/regularization_loss': 0.12377021,
#  'Loss/total_loss': 0.20987055,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.246s
# I0512 16:02:14.981920  8752 model_lib_v2.py:705] Step 5100 per-step time 0.246s
# INFO:tensorflow:{'Loss/classification_loss': 0.017744308,
#  'Loss/localization_loss': 0.012976282,
#  'Loss/regularization_loss': 0.123132765,
#  'Loss/total_loss': 0.15385336,
#  'learning_rate': 0.07862595}
# I0512 16:02:14.981920  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.017744308,
#  'Loss/localization_loss': 0.012976282,
#  'Loss/regularization_loss': 0.123132765,
#  'Loss/total_loss': 0.15385336,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.224s
# I0512 16:02:37.384163  8752 model_lib_v2.py:705] Step 5200 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.032946628,
#  'Loss/localization_loss': 0.012384658,
#  'Loss/regularization_loss': 0.12246284,
#  'Loss/total_loss': 0.16779412,
#  'learning_rate': 0.07855851}
# I0512 16:02:37.385163  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.032946628,
#  'Loss/localization_loss': 0.012384658,
#  'Loss/regularization_loss': 0.12246284,
#  'Loss/total_loss': 0.16779412,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.220s
# I0512 16:02:59.287186  8752 model_lib_v2.py:705] Step 5300 per-step time 0.220s
# INFO:tensorflow:{'Loss/classification_loss': 0.056390777,
#  'Loss/localization_loss': 0.04125263,
#  'Loss/regularization_loss': 0.1218162,
#  'Loss/total_loss': 0.21945961,
#  'learning_rate': 0.07848949}
# I0512 16:02:59.288188  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.056390777,
#  'Loss/localization_loss': 0.04125263,
#  'Loss/regularization_loss': 0.1218162,
#  'Loss/total_loss': 0.21945961,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.219s
# I0512 16:03:22.895554  8752 model_lib_v2.py:705] Step 5400 per-step time 0.219s
# INFO:tensorflow:{'Loss/classification_loss': 0.023010867,
#  'Loss/localization_loss': 0.015401897,
#  'Loss/regularization_loss': 0.121177025,
#  'Loss/total_loss': 0.1595898,
#  'learning_rate': 0.078418896}
# I0512 16:03:22.895554  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.023010867,
#  'Loss/localization_loss': 0.015401897,
#  'Loss/regularization_loss': 0.121177025,
#  'Loss/total_loss': 0.1595898,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.235s
# I0512 16:03:44.721481  8752 model_lib_v2.py:705] Step 5500 per-step time 0.235s
# INFO:tensorflow:{'Loss/classification_loss': 0.038117513,
#  'Loss/localization_loss': 0.015740085,
#  'Loss/regularization_loss': 0.12055361,
#  'Loss/total_loss': 0.1744112,
#  'learning_rate': 0.078346714}
# I0512 16:03:44.721481  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.038117513,
#  'Loss/localization_loss': 0.015740085,
#  'Loss/regularization_loss': 0.12055361,
#  'Loss/total_loss': 0.1744112,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.219s
# I0512 16:04:06.582858  8752 model_lib_v2.py:705] Step 5600 per-step time 0.219s
# INFO:tensorflow:{'Loss/classification_loss': 0.051033903,
#  'Loss/localization_loss': 0.030671407,
#  'Loss/regularization_loss': 0.11993819,
#  'Loss/total_loss': 0.2016435,
#  'learning_rate': 0.07827295}
# I0512 16:04:06.582858  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.051033903,
#  'Loss/localization_loss': 0.030671407,
#  'Loss/regularization_loss': 0.11993819,
#  'Loss/total_loss': 0.2016435,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.214s
# I0512 16:04:29.078586  8752 model_lib_v2.py:705] Step 5700 per-step time 0.214s
# INFO:tensorflow:{'Loss/classification_loss': 0.025860887,
#  'Loss/localization_loss': 0.015621539,
#  'Loss/regularization_loss': 0.1193048,
#  'Loss/total_loss': 0.16078722,
#  'learning_rate': 0.07819763}
# I0512 16:04:29.078586  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.025860887,
#  'Loss/localization_loss': 0.015621539,
#  'Loss/regularization_loss': 0.1193048,
#  'Loss/total_loss': 0.16078722,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.229s
# I0512 16:04:50.944697  8752 model_lib_v2.py:705] Step 5800 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.022085262,
#  'Loss/localization_loss': 0.0075718462,
#  'Loss/regularization_loss': 0.11868451,
#  'Loss/total_loss': 0.14834161,
#  'learning_rate': 0.07812072}
# I0512 16:04:50.944697  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.022085262,
#  'Loss/localization_loss': 0.0075718462,
#  'Loss/regularization_loss': 0.11868451,
#  'Loss/total_loss': 0.14834161,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.224s
# I0512 16:05:13.362198  8752 model_lib_v2.py:705] Step 5900 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.087425366,
#  'Loss/localization_loss': 0.033255037,
#  'Loss/regularization_loss': 0.11810034,
#  'Loss/total_loss': 0.23878074,
#  'learning_rate': 0.078042254}
# I0512 16:05:13.363205  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.087425366,
#  'Loss/localization_loss': 0.033255037,
#  'Loss/regularization_loss': 0.11810034,
#  'Loss/total_loss': 0.23878074,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.232s
# I0512 16:05:36.563452  8752 model_lib_v2.py:705] Step 6000 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.039059404,
#  'Loss/localization_loss': 0.015221581,
#  'Loss/regularization_loss': 0.11750721,
#  'Loss/total_loss': 0.1717882,
#  'learning_rate': 0.07796223}
# I0512 16:05:36.564463  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.039059404,
#  'Loss/localization_loss': 0.015221581,
#  'Loss/regularization_loss': 0.11750721,
#  'Loss/total_loss': 0.1717882,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.246s
# I0512 16:06:01.145747  8752 model_lib_v2.py:705] Step 6100 per-step time 0.246s
# INFO:tensorflow:{'Loss/classification_loss': 0.081943534,
#  'Loss/localization_loss': 0.011959058,
#  'Loss/regularization_loss': 0.11689991,
#  'Loss/total_loss': 0.2108025,
#  'learning_rate': 0.077880636}
# I0512 16:06:01.145747  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.081943534,
#  'Loss/localization_loss': 0.011959058,
#  'Loss/regularization_loss': 0.11689991,
#  'Loss/total_loss': 0.2108025,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.216s
# I0512 16:06:23.153362  8752 model_lib_v2.py:705] Step 6200 per-step time 0.216s
# INFO:tensorflow:{'Loss/classification_loss': 0.05087838,
#  'Loss/localization_loss': 0.0181424,
#  'Loss/regularization_loss': 0.11631509,
#  'Loss/total_loss': 0.18533587,
#  'learning_rate': 0.07779749}
# I0512 16:06:23.154361  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.05087838,
#  'Loss/localization_loss': 0.0181424,
#  'Loss/regularization_loss': 0.11631509,
#  'Loss/total_loss': 0.18533587,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 0.222s
# I0512 16:06:45.317129  8752 model_lib_v2.py:705] Step 6300 per-step time 0.222s
# INFO:tensorflow:{'Loss/classification_loss': 0.034358688,
#  'Loss/localization_loss': 0.008863693,
#  'Loss/regularization_loss': 0.115710065,
#  'Loss/total_loss': 0.15893245,
#  'learning_rate': 0.07771279}
# I0512 16:06:45.317129  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.034358688,
#  'Loss/localization_loss': 0.008863693,
#  'Loss/regularization_loss': 0.115710065,
#  'Loss/total_loss': 0.15893245,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.222s
# I0512 16:07:07.085391  8752 model_lib_v2.py:705] Step 6400 per-step time 0.222s
# INFO:tensorflow:{'Loss/classification_loss': 0.055227652,
#  'Loss/localization_loss': 0.030361548,
#  'Loss/regularization_loss': 0.11509538,
#  'Loss/total_loss': 0.20068458,
#  'learning_rate': 0.077626534}
# I0512 16:07:07.085391  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.055227652,
#  'Loss/localization_loss': 0.030361548,
#  'Loss/regularization_loss': 0.11509538,
#  'Loss/total_loss': 0.20068458,
#  'learning_rate': 0.077626534}
# INFO:tensorflow:Step 6500 per-step time 0.216s
# I0512 16:07:30.409212  8752 model_lib_v2.py:705] Step 6500 per-step time 0.216s
# INFO:tensorflow:{'Loss/classification_loss': 0.04019795,
#  'Loss/localization_loss': 0.009088245,
#  'Loss/regularization_loss': 0.11447991,
#  'Loss/total_loss': 0.1637661,
#  'learning_rate': 0.077538736}
# I0512 16:07:30.409212  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.04019795,
# ...
#  'Loss/localization_loss': 0.015133324,
#  'Loss/regularization_loss': 0.07009551,
#  'Loss/total_loss': 0.10560642,
#  'learning_rate': 0.060295396}
# INFO:tensorflow:Step 17300 per-step time 0.225s
# I0512 16:48:36.858520  8752 model_lib_v2.py:705] Step 17300 per-step time 0.225s
# INFO:tensorflow:{'Loss/classification_loss': 0.01756901,
#  'Loss/localization_loss': 0.0052970517,
#  'Loss/regularization_loss': 0.06983138,
#  'Loss/total_loss': 0.09269744,
#  'learning_rate': 0.060073983}
# I0512 16:48:36.859521  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.01756901,
#  'Loss/localization_loss': 0.0052970517,
#  'Loss/regularization_loss': 0.06983138,
#  'Loss/total_loss': 0.09269744,
#  'learning_rate': 0.060073983}
# INFO:tensorflow:Step 17400 per-step time 0.220s
# I0512 16:48:58.495942  8752 model_lib_v2.py:705] Step 17400 per-step time 0.220s
# INFO:tensorflow:{'Loss/classification_loss': 0.022998715,
#  'Loss/localization_loss': 0.011290647,
#  'Loss/regularization_loss': 0.069561884,
#  'Loss/total_loss': 0.103851244,
#  'learning_rate': 0.05985175}
# I0512 16:48:58.496942  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.022998715,
#  'Loss/localization_loss': 0.011290647,
#  'Loss/regularization_loss': 0.069561884,
#  'Loss/total_loss': 0.103851244,
#  'learning_rate': 0.05985175}
# INFO:tensorflow:Step 17500 per-step time 0.227s
# I0512 16:49:22.904455  8752 model_lib_v2.py:705] Step 17500 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.032776337,
#  'Loss/localization_loss': 0.014028672,
#  'Loss/regularization_loss': 0.06929492,
#  'Loss/total_loss': 0.11609993,
#  'learning_rate': 0.0596287}
# I0512 16:49:22.905456  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.032776337,
#  'Loss/localization_loss': 0.014028672,
#  'Loss/regularization_loss': 0.06929492,
#  'Loss/total_loss': 0.11609993,
#  'learning_rate': 0.0596287}
# INFO:tensorflow:Step 17600 per-step time 0.237s
# I0512 16:49:45.258982  8752 model_lib_v2.py:705] Step 17600 per-step time 0.237s
# INFO:tensorflow:{'Loss/classification_loss': 0.031892944,
#  'Loss/localization_loss': 0.006526517,
#  'Loss/regularization_loss': 0.069024675,
#  'Loss/total_loss': 0.10744414,
#  'learning_rate': 0.05940484}
# I0512 16:49:45.258982  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.031892944,
#  'Loss/localization_loss': 0.006526517,
#  'Loss/regularization_loss': 0.069024675,
#  'Loss/total_loss': 0.10744414,
#  'learning_rate': 0.05940484}
# INFO:tensorflow:Step 17700 per-step time 0.218s
# I0512 16:50:06.645342  8752 model_lib_v2.py:705] Step 17700 per-step time 0.218s
# INFO:tensorflow:{'Loss/classification_loss': 0.040309515,
#  'Loss/localization_loss': 0.00510079,
#  'Loss/regularization_loss': 0.0687576,
#  'Loss/total_loss': 0.11416791,
#  'learning_rate': 0.059180185}
# I0512 16:50:06.646343  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.040309515,
#  'Loss/localization_loss': 0.00510079,
#  'Loss/regularization_loss': 0.0687576,
#  'Loss/total_loss': 0.11416791,
#  'learning_rate': 0.059180185}
# INFO:tensorflow:Step 17800 per-step time 0.212s
# I0512 16:50:29.686981  8752 model_lib_v2.py:705] Step 17800 per-step time 0.212s
# INFO:tensorflow:{'Loss/classification_loss': 0.043885414,
#  'Loss/localization_loss': 0.010162762,
#  'Loss/regularization_loss': 0.06849299,
#  'Loss/total_loss': 0.122541174,
#  'learning_rate': 0.05895474}
# I0512 16:50:29.687944  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.043885414,
#  'Loss/localization_loss': 0.010162762,
#  'Loss/regularization_loss': 0.06849299,
#  'Loss/total_loss': 0.122541174,
#  'learning_rate': 0.05895474}
# INFO:tensorflow:Step 17900 per-step time 0.235s
# I0512 16:50:51.405956  8752 model_lib_v2.py:705] Step 17900 per-step time 0.235s
# INFO:tensorflow:{'Loss/classification_loss': 0.019980028,
#  'Loss/localization_loss': 0.0044633094,
#  'Loss/regularization_loss': 0.06822701,
#  'Loss/total_loss': 0.092670344,
#  'learning_rate': 0.058728524}
# I0512 16:50:51.405956  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.019980028,
#  'Loss/localization_loss': 0.0044633094,
#  'Loss/regularization_loss': 0.06822701,
#  'Loss/total_loss': 0.092670344,
#  'learning_rate': 0.058728524}
# INFO:tensorflow:Step 18000 per-step time 0.223s
# I0512 16:51:13.729721  8752 model_lib_v2.py:705] Step 18000 per-step time 0.223s
# INFO:tensorflow:{'Loss/classification_loss': 0.035897247,
#  'Loss/localization_loss': 0.012207786,
#  'Loss/regularization_loss': 0.06796785,
#  'Loss/total_loss': 0.11607288,
#  'learning_rate': 0.058501527}
# I0512 16:51:13.730733  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.035897247,
#  'Loss/localization_loss': 0.012207786,
#  'Loss/regularization_loss': 0.06796785,
#  'Loss/total_loss': 0.11607288,
#  'learning_rate': 0.058501527}
# INFO:tensorflow:Step 18100 per-step time 0.243s
# I0512 16:51:38.412257  8752 model_lib_v2.py:705] Step 18100 per-step time 0.243s
# INFO:tensorflow:{'Loss/classification_loss': 0.10552206,
#  'Loss/localization_loss': 0.034971125,
#  'Loss/regularization_loss': 0.06771036,
#  'Loss/total_loss': 0.20820355,
#  'learning_rate': 0.058273777}
# I0512 16:51:38.412257  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.10552206,
#  'Loss/localization_loss': 0.034971125,
#  'Loss/regularization_loss': 0.06771036,
#  'Loss/total_loss': 0.20820355,
#  'learning_rate': 0.058273777}
# INFO:tensorflow:Step 18200 per-step time 0.222s
# I0512 16:52:00.221402  8752 model_lib_v2.py:705] Step 18200 per-step time 0.222s
# INFO:tensorflow:{'Loss/classification_loss': 0.020221684,
#  'Loss/localization_loss': 0.005373816,
#  'Loss/regularization_loss': 0.06745327,
#  'Loss/total_loss': 0.09304877,
#  'learning_rate': 0.05804527}
# I0512 16:52:00.222413  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.020221684,
#  'Loss/localization_loss': 0.005373816,
#  'Loss/regularization_loss': 0.06745327,
#  'Loss/total_loss': 0.09304877,
#  'learning_rate': 0.05804527}
# INFO:tensorflow:Step 18300 per-step time 0.216s
# I0512 16:52:23.652302  8752 model_lib_v2.py:705] Step 18300 per-step time 0.216s
# INFO:tensorflow:{'Loss/classification_loss': 0.022921054,
#  'Loss/localization_loss': 0.009158787,
#  'Loss/regularization_loss': 0.06719571,
#  'Loss/total_loss': 0.09927556,
#  'learning_rate': 0.05781603}
# I0512 16:52:23.652302  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.022921054,
#  'Loss/localization_loss': 0.009158787,
#  'Loss/regularization_loss': 0.06719571,
#  'Loss/total_loss': 0.09927556,
#  'learning_rate': 0.05781603}
# INFO:tensorflow:Step 18400 per-step time 0.229s
# I0512 16:52:45.121340  8752 model_lib_v2.py:705] Step 18400 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.032504797,
#  'Loss/localization_loss': 0.006138039,
#  'Loss/regularization_loss': 0.06692626,
#  'Loss/total_loss': 0.105569094,
#  'learning_rate': 0.057586048}
# I0512 16:52:45.121340  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.032504797,
#  'Loss/localization_loss': 0.006138039,
#  'Loss/regularization_loss': 0.06692626,
#  'Loss/total_loss': 0.105569094,
#  'learning_rate': 0.057586048}
# INFO:tensorflow:Step 18500 per-step time 0.222s
# I0512 16:53:06.965306  8752 model_lib_v2.py:705] Step 18500 per-step time 0.222s
# INFO:tensorflow:{'Loss/classification_loss': 0.040577326,
#  'Loss/localization_loss': 0.021073122,
#  'Loss/regularization_loss': 0.066670835,
#  'Loss/total_loss': 0.12832129,
#  'learning_rate': 0.05735535}
# I0512 16:53:06.966315  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.040577326,
#  'Loss/localization_loss': 0.021073122,
#  'Loss/regularization_loss': 0.066670835,
#  'Loss/total_loss': 0.12832129,
#  'learning_rate': 0.05735535}
# INFO:tensorflow:Step 18600 per-step time 0.228s
# I0512 16:53:31.466202  8752 model_lib_v2.py:705] Step 18600 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.042351194,
#  'Loss/localization_loss': 0.007313992,
#  'Loss/regularization_loss': 0.06642471,
#  'Loss/total_loss': 0.116089895,
#  'learning_rate': 0.057123937}
# I0512 16:53:31.466202  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.042351194,
#  'Loss/localization_loss': 0.007313992,
#  'Loss/regularization_loss': 0.06642471,
#  'Loss/total_loss': 0.116089895,
#  'learning_rate': 0.057123937}
# INFO:tensorflow:Step 18700 per-step time 0.247s
# I0512 16:53:54.500870  8752 model_lib_v2.py:705] Step 18700 per-step time 0.247s
# INFO:tensorflow:{'Loss/classification_loss': 0.014437404,
#  'Loss/localization_loss': 0.0055373036,
#  'Loss/regularization_loss': 0.066186704,
#  'Loss/total_loss': 0.08616141,
#  'learning_rate': 0.056891818}
# I0512 16:53:54.501871  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.014437404,
#  'Loss/localization_loss': 0.0055373036,
#  'Loss/regularization_loss': 0.066186704,
#  'Loss/total_loss': 0.08616141,
#  'learning_rate': 0.056891818}
# INFO:tensorflow:Step 18800 per-step time 0.231s
# I0512 16:54:17.431351  8752 model_lib_v2.py:705] Step 18800 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.024819551,
#  'Loss/localization_loss': 0.007935357,
#  'Loss/regularization_loss': 0.06593593,
#  'Loss/total_loss': 0.09869084,
#  'learning_rate': 0.056659}
# I0512 16:54:17.432384  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.024819551,
#  'Loss/localization_loss': 0.007935357,
#  'Loss/regularization_loss': 0.06593593,
#  'Loss/total_loss': 0.09869084,
#  'learning_rate': 0.056659}
# INFO:tensorflow:Step 18900 per-step time 0.228s
# I0512 16:54:41.931016  8752 model_lib_v2.py:705] Step 18900 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.0266321,
#  'Loss/localization_loss': 0.024505341,
#  'Loss/regularization_loss': 0.06568542,
#  'Loss/total_loss': 0.11682286,
#  'learning_rate': 0.056425504}
# I0512 16:54:41.931016  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.0266321,
#  'Loss/localization_loss': 0.024505341,
#  'Loss/regularization_loss': 0.06568542,
#  'Loss/total_loss': 0.11682286,
#  'learning_rate': 0.056425504}
# INFO:tensorflow:Step 19000 per-step time 0.235s
# I0512 16:55:03.677378  8752 model_lib_v2.py:705] Step 19000 per-step time 0.235s
# INFO:tensorflow:{'Loss/classification_loss': 0.03280926,
#  'Loss/localization_loss': 0.011920052,
#  'Loss/regularization_loss': 0.065452,
#  'Loss/total_loss': 0.11018132,
#  'learning_rate': 0.056191333}
# I0512 16:55:03.677378  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.03280926,
#  'Loss/localization_loss': 0.011920052,
#  'Loss/regularization_loss': 0.065452,
#  'Loss/total_loss': 0.11018132,
#  'learning_rate': 0.056191333}
# INFO:tensorflow:Step 19100 per-step time 0.241s
# I0512 16:55:27.828629  8752 model_lib_v2.py:705] Step 19100 per-step time 0.241s
# INFO:tensorflow:{'Loss/classification_loss': 0.019918669,
#  'Loss/localization_loss': 0.005042522,
#  'Loss/regularization_loss': 0.06522341,
#  'Loss/total_loss': 0.0901846,
#  'learning_rate': 0.055956498}
# I0512 16:55:27.829637  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.019918669,
#  'Loss/localization_loss': 0.005042522,
#  'Loss/regularization_loss': 0.06522341,
#  'Loss/total_loss': 0.0901846,
#  'learning_rate': 0.055956498}
# INFO:tensorflow:Step 19200 per-step time 0.222s
# I0512 16:55:50.397562  8752 model_lib_v2.py:705] Step 19200 per-step time 0.222s
# INFO:tensorflow:{'Loss/classification_loss': 0.046287015,
#  'Loss/localization_loss': 0.0050442964,
#  'Loss/regularization_loss': 0.06501901,
#  'Loss/total_loss': 0.11635032,
#  'learning_rate': 0.055721}
# I0512 16:55:50.397562  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.046287015,
#  'Loss/localization_loss': 0.0050442964,
#  'Loss/regularization_loss': 0.06501901,
#  'Loss/total_loss': 0.11635032,
#  'learning_rate': 0.055721}
# INFO:tensorflow:Step 19300 per-step time 0.221s
# I0512 16:56:12.135386  8752 model_lib_v2.py:705] Step 19300 per-step time 0.221s
# INFO:tensorflow:{'Loss/classification_loss': 0.02472489,
#  'Loss/localization_loss': 0.0048698955,
#  'Loss/regularization_loss': 0.064803176,
#  'Loss/total_loss': 0.09439796,
#  'learning_rate': 0.05548486}
# I0512 16:56:12.136388  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.02472489,
#  'Loss/localization_loss': 0.0048698955,
#  'Loss/regularization_loss': 0.064803176,
#  'Loss/total_loss': 0.09439796,
#  'learning_rate': 0.05548486}
# INFO:tensorflow:Step 19400 per-step time 0.222s
# I0512 16:56:36.114710  8752 model_lib_v2.py:705] Step 19400 per-step time 0.222s
# INFO:tensorflow:{'Loss/classification_loss': 0.01919112,
#  'Loss/localization_loss': 0.012771028,
#  'Loss/regularization_loss': 0.06456406,
#  'Loss/total_loss': 0.096526206,
#  'learning_rate': 0.05524808}
# I0512 16:56:36.114710  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.01919112,
#  'Loss/localization_loss': 0.012771028,
#  'Loss/regularization_loss': 0.06456406,
#  'Loss/total_loss': 0.096526206,
#  'learning_rate': 0.05524808}
# INFO:tensorflow:Step 19500 per-step time 0.236s
# I0512 16:56:58.394008  8752 model_lib_v2.py:705] Step 19500 per-step time 0.236s
# INFO:tensorflow:{'Loss/classification_loss': 0.04780292,
#  'Loss/localization_loss': 0.014283746,
#  'Loss/regularization_loss': 0.06433068,
#  'Loss/total_loss': 0.12641735,
#  'learning_rate': 0.05501068}
# I0512 16:56:58.394008  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.04780292,
#  'Loss/localization_loss': 0.014283746,
#  'Loss/regularization_loss': 0.06433068,
#  'Loss/total_loss': 0.12641735,
#  'learning_rate': 0.05501068}
# INFO:tensorflow:Step 19600 per-step time 0.224s
# I0512 16:57:20.315417  8752 model_lib_v2.py:705] Step 19600 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.026957257,
#  'Loss/localization_loss': 0.0047421427,
#  'Loss/regularization_loss': 0.06410725,
#  'Loss/total_loss': 0.09580664,
#  'learning_rate': 0.054772656}
# I0512 16:57:20.316415  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.026957257,
#  'Loss/localization_loss': 0.0047421427,
#  'Loss/regularization_loss': 0.06410725,
#  'Loss/total_loss': 0.09580664,
#  'learning_rate': 0.054772656}
# INFO:tensorflow:Step 19700 per-step time 0.226s
# I0512 16:57:43.060521  8752 model_lib_v2.py:705] Step 19700 per-step time 0.226s
# INFO:tensorflow:{'Loss/classification_loss': 0.0073359534,
#  'Loss/localization_loss': 0.0024149127,
#  'Loss/regularization_loss': 0.06389858,
#  'Loss/total_loss': 0.07364944,
#  'learning_rate': 0.05453403}
# I0512 16:57:43.060521  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.0073359534,
#  'Loss/localization_loss': 0.0024149127,
#  'Loss/regularization_loss': 0.06389858,
#  'Loss/total_loss': 0.07364944,
#  'learning_rate': 0.05453403}
# INFO:tensorflow:Step 19800 per-step time 0.247s
# I0512 16:58:08.094183  8752 model_lib_v2.py:705] Step 19800 per-step time 0.247s
# INFO:tensorflow:{'Loss/classification_loss': 0.03299049,
#  'Loss/localization_loss': 0.006263111,
#  'Loss/regularization_loss': 0.06366814,
#  'Loss/total_loss': 0.10292174,
#  'learning_rate': 0.0542948}
# I0512 16:58:08.095208  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.03299049,
#  'Loss/localization_loss': 0.006263111,
#  'Loss/regularization_loss': 0.06366814,
#  'Loss/total_loss': 0.10292174,
#  'learning_rate': 0.0542948}
# INFO:tensorflow:Step 19900 per-step time 0.229s
# I0512 16:58:30.563933  8752 model_lib_v2.py:705] Step 19900 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.01932936,
#  'Loss/localization_loss': 0.0045576966,
#  'Loss/regularization_loss': 0.06343961,
#  'Loss/total_loss': 0.08732666,
#  'learning_rate': 0.054054994}
# I0512 16:58:30.563933  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.01932936,
#  'Loss/localization_loss': 0.0045576966,
#  'Loss/regularization_loss': 0.06343961,
#  'Loss/total_loss': 0.08732666,
#  'learning_rate': 0.054054994}
# INFO:tensorflow:Step 20000 per-step time 0.224s
# I0512 16:58:53.032438  8752 model_lib_v2.py:705] Step 20000 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.061658017,
#  'Loss/localization_loss': 0.021945203,
#  'Loss/regularization_loss': 0.063218005,
#  'Loss/total_loss': 0.14682123,
#  'learning_rate': 0.0538146}
# I0512 16:58:53.033438  8752 model_lib_v2.py:708] {'Loss/classification_loss': 0.061658017,
#  'Loss/localization_loss': 0.021945203,
#  'Loss/regularization_loss': 0.063218005,
#  'Loss/total_loss': 0.14682123,
#  'learning_rate': 0.0538146}
